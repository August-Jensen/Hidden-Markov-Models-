# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm
# insert code here
import matplotlib.dates as mdates
import seaborn as sns
import importlib
import HamiltonFilter

data = pd.read_csv('SP.csv', sep=';')

data['Date'] = pd.to_datetime(data['Date'])
data = data.iloc[500:1000]
plt.figure(figsize=(15, 6))
plt.plot(data['Date'], data['Return'])
plt.xlabel('Year')
plt.ylabel('Returns')
plt.title('Daily Returns from 1950 to Present')

# Setting x-axis to show only the years
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
importlib.reload(HamiltonFilter)
from HamiltonFilter import BaseFilter as ham
# print(my_data)
# Example usage
n_states = 2  # or whatever your number of states is
y = data['Return'].to_numpy()
hf = ham(y, n_states)
hf.fit()
# sigma2 = np.var(y)
# Gamma0 = np.array([0.95, 0.95, np.sqrt(2*sigma2), np.sqrt(0.5*sigma2)])
# bounds = ((0.001, 0.9999), (0.001, 0.9999), (0.01, None), (0.01, None))

# Gamma_hat, se_hessian = hf.fit(Gamma0, bounds)
# Out:
# Estimation Parameters: [3.   2.   0.95 0.05]
# Combined Bounds: [(0.001, None), (0.001, None), (0.001, 0.9999), (0.001, 0.9999)]
# [[0.95 0.05]
#  [0.05 0.95]]
# Total log-likelihood:  99.75781754465912
# Iteration: 0
# [[0.95 0.05]
#  [0.05 0.95]]
# Total log-likelihood:  99.75781735472006
# Iteration: 1
# [[0.95 0.05]
#  [0.05 0.95]]
# Total log-likelihood:  99.75781700392389
# Iteration: 2
# [[0.95000001 0.05      ]
#  [0.04999999 0.95      ]]
# Total log-likelihood:  99.75781754465912
# Iteration: 3
# [[0.95       0.05000001]
#  [0.05       0.94999999]]
# Total log-likelihood:  99.75781754465912
# Iteration: 4
# [[0.95 0.05]
#  [0.05 0.95]]
# Total log-likelihood:  62.829873327222344
# Iteration: 5
# [[0.95 0.05]
#  [0.05 0.95]]
# Total log-likelihood:  62.82987318333508
# Iteration: 6
# [[0.95 0.05]
#  [0.05 0.95]]
# Total log-likelihood:  62.82987312750602
# Iteration: 7
# [[0.95000001 0.05      ]
#  [0.04999999 0.95      ]]
# Total log-likelihood:  62.829873327222344
# ...
