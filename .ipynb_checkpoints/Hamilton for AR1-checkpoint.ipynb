# %% [markdown]
# # Hamilton Algorithm for Comparing AR(1) with Statsmodels Markov Autoregression

# %% [markdown]
# This code aims to establish a Hamilton algorithm for an AR(1) model, with n states, and then comparing Filters performance with the one from Statsmodels.

# %%
# insert code here
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt #pyplot is used to plot the data
import scipy.optimize as opt #used to numerically optimize
from datetime import time, timedelta, datetime
import importlib

# Import Dataframe
df = pd.read_csv('SP500.csv', sep=';')
df['pct'] = df['Return'] * 100
df['cum'] = df['Return'].cumsum()
df
# Out:
#        Unnamed: 0        Date    Return       pct       cum
# 0               0  1950-01-04  0.000000  0.000000  0.000000
# 1               1  1950-01-05  0.004737  0.473654  0.004737
# 2               2  1950-01-06  0.002949  0.294898  0.007686
# 3               3  1950-01-09  0.005872  0.587201  0.013558
# 4               4  1950-01-10 -0.002932 -0.293163  0.010626
# ...           ...         ...       ...       ...       ...
# 18444       18444  2023-04-24  0.000851  0.085122  5.503385
# 18445       18445  2023-04-25 -0.015937 -1.593718  5.487448
# 18446       18446  2023-04-26 -0.003849 -0.384858  5.483599
# 18447       18447  2023-04-27  0.019377  1.937719  5.502977
# 18448       18448  2023-04-28  0.008219  0.821933  5.511196
#
# [18449 rows x 5 columns]

# %% [markdown]
# ## Hamilton Filter

# %% [markdown]
# I first create a Model, that can calculate the likelihood, fit the model, plot filtered and smoothed probabilities, the estimated model, the observed data, and the residuals, and provide tesst statistics.

# %%
import Hamilton
importlib.reload(Hamilton)
# model = Hamilton.fit(df['pct'], n_states=2)
# log_likelihood_contribution = model.log_likelihood_contribution(t=1, state=0)



# Step 1: Load your data (this is just a placeholder; replace it with your data)
# y = np.random.randn(100)  # Replace with your actual time series data
y = df['pct']

# Step 2: Initialize the HamiltonFilter model
# These are arbitrary initial values; replace them with your actual initial guesses
initial_sigma2 = np.var(y)
initial_params = np.array([0.95, 0.95, np.sqrt(2 * initial_sigma2), np.sqrt(0.5 * initial_sigma2)])
bounds = [(0.001, 0.9999), (0.001, 0.9999), (0.01, None), (0.01, None)]

model = Hamilton.HamiltonFilter(n_states=2, sigma2=initial_params[2:4] ** 2, p00=initial_params[0], p11=initial_params[1])

# Step 3: Optimize parameters
estimated_params, standard_errors = model.optimize_parameters(y, initial_params, bounds)

# Step 4: Run the filter
xi_10, xi_11, xi_1T = model.forward_backward_filter(y, model.transition_matrix, model.sigma2)

# Compute filtered volatility
vol = xi_11[0, :] * model.sigma2[0] + (1 - xi_11[0, :]) * model.sigma2[1]

# Step 5: Plot the results
model.plot_results(y, vol)
model.plot_probabilities(xi_10, xi_11, xi_1T, len(y))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 21
#      18 model = Hamilton.HamiltonFilter(n_states=3, sigma2=initial_params[2:4] ** 2, p00=initial_params[0], p11=initial_params[1])
#      20 # Step 3: Optimize parameters
# ---> 21 estimated_params, standard_errors = model.optimize_parameters(y, initial_params, bounds)
#      23 # Step 4: Run the filter
#      24 xi_10, xi_11, xi_1T = model.forward_backward_filter(y, model.transition_matrix, model.sigma2)
#
# File ~/code/jupyter/Markov/Hamilton.py:66, in HamiltonFilter.optimize_parameters(self, y, initial_params, bounds)
#      65 def optimize_parameters(self, y, initial_params, bounds):
# ---> 66     result = minimize(self.run_filter, initial_params, args=(y,), method='L-BFGS-B', bounds=bounds)
#      67     estimated_params = result.x
#      68     variance_hessian = result.hess_inv.todense()
#
# File ~/.venvs/jupyter/lib/python3.11/site-packages/scipy/optimize/_minimize.py:710, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     707     res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     708                              **options)
#     709 elif meth == 'l-bfgs-b':
# --> 710     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     711                            callback=callback, **options)
#     712 elif meth == 'tnc':
#     713     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     714                         **options)
#
# File ~/.venvs/jupyter/lib/python3.11/site-packages/scipy/optimize/_lbfgsb_py.py:307, in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     304     else:
#     305         iprint = disp
# --> 307 sf = _prepare_scalar_function(fun, x0, jac=jac, args=args, epsilon=eps,
#     308                               bounds=new_bounds,
#     309                               finite_diff_rel_step=finite_diff_rel_step)
#     311 func_and_grad = sf.fun_and_grad
#     313 fortran_int = _lbfgsb.types.intvar.dtype
#
# File ~/.venvs/jupyter/lib/python3.11/site-packages/scipy/optimize/_optimize.py:383, in _prepare_scalar_function(fun, x0, jac, args, bounds, epsilon, finite_diff_rel_step, hess)
#     379     bounds = (-np.inf, np.inf)
#     381 # ScalarFunction caches. Reuse of fun(x) during grad
#     382 # calculation reduces overall function evaluations.
# --> 383 sf = ScalarFunction(fun, x0, args, grad, hess,
#     384                     finite_diff_rel_step, bounds, epsilon=epsilon)
#     386 return sf
#
# File ~/.venvs/jupyter/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py:158, in ScalarFunction.__init__(self, fun, x0, args, grad, hess, finite_diff_rel_step, finite_diff_bounds, epsilon)
#     155     self.f = fun_wrapped(self.x)
#     157 self._update_fun_impl = update_fun
# --> 158 self._update_fun()
#     160 # Gradient evaluation
#     161 if callable(grad):
#
# File ~/.venvs/jupyter/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py:251, in ScalarFunction._update_fun(self)
#     249 def _update_fun(self):
#     250     if not self.f_updated:
# --> 251         self._update_fun_impl()
#     252         self.f_updated = True
#
# File ~/.venvs/jupyter/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py:155, in ScalarFunction.__init__.<locals>.update_fun()
#     154 def update_fun():
# --> 155     self.f = fun_wrapped(self.x)
#
# File ~/.venvs/jupyter/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py:137, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     133 self.nfev += 1
#     134 # Send a copy because the user may overwrite it.
#     135 # Overwriting results in undefined behaviour because
#     136 # fun(self.x) will change self.x, with the two no longer linked.
# --> 137 fx = fun(np.copy(x), *args)
#     138 # Make sure the function returns a true scalar
#     139 if not np.isscalar(fx):
#
# File ~/code/jupyter/Markov/Hamilton.py:55, in HamiltonFilter.run_filter(self, initial_params, y)
#      51 eta = np.array([self.GaussianDensity(y[t], 0, self.sigma2[0]),
#      52                 self.GaussianDensity(y[t], 0, self.sigma2[1])])
#      54 # Likelihood
# ---> 55 likelihoods[t] = np.log(np.dot(xi_10[:, t], eta))
#      57 # Filtering
#      58 xi_11[:, t] = self.filter_step(y[t], xi_10[:, t])
#
# ValueError: shapes (3,) and (2,) not aligned: 3 (dim 0) != 2 (dim 0)
